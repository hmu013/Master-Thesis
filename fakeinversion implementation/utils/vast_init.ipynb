# %%
# %pip install -U \
    torch torchvision \
    diffusers \
    accelerate \
    transformers \
    huggingface_hub \
    webdataset \
    albumentations \
    tqdm \
    pillow

# %%
# !curl -LsSf https://hf.co/cli/install.sh | bash

# !hf auth login

# %%
# !sudo apt-get install -y btop
